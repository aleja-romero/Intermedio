# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
x = [413,403,393,383,373,363,353,343,333,323,313,303]

y = [0.468,0.621,0.806,1.018,1.199,1.315,1.35,1.32,1.259,1.185,1.111,1.037]

plt.figure(figsize=(10, 6))

plt.plot(x, y, 'o')  



plt.xlabel("T (K)")
plt.ylabel('V_l (V)')
plt.title("T vs V_l")
plt.legend()
plt.grid(True)


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x = [413,403,393,383,373,363,353,343,333,323,313,303]

y = [23,30,49,81,121,171,204,223,232,235,236,237]

plt.figure(figsize=(10, 6))

plt.plot(x, y, 'o')  



plt.xlabel("T (K)")
plt.ylabel('V_h (mV)')
plt.title("T vs V_h")
plt.legend()
plt.grid(True)


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
